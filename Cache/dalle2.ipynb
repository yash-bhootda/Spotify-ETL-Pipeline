# %%
pip install --upgrade openai
# Out:
# ...
#
# ...
#      -------------------------------------- 70.1/70.1 kB 478.8 kB/s eta 0:00:00
# ...

# %%
# !pip install ipykernel
# Out:
# Running cells with 'yash' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n yash ipykernel --update-deps --force-reinstall'

# %%
import openai
openai.api_key = "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"  # supply your API key however you choose

image_resp = openai.Image.create(prompt="two dogs playing chess, oil painting", n=1, size="512x512")

# %%
# !pip install --upgrade prompt-toolkit
# Out:
# The kernel failed to start due to the missing module 'prompt_toolkit.formatted_text'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util
# Out:
# The kernel failed to start due to the missing module 'prompt_toolkit.formatted_text'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
client_id = "b7ed80b8ba7e4e0297457b4063c3a375"
client_secret = "53bc721903df42caad1964b87821ddd2"
scope = 'playlist-modify-public user-read-recently-played user-top-read ugc-image-upload'
username='qy898dz5521ijiuw4ih2l00qu'
token = util.prompt_for_user_token(username , scope, client_id= client_id, client_secret=client_secret, redirect_uri='http://localhost:8080')
sp = spotipy.Spotify(auth=token)

# %%
playlist_name_recommend = "Recommendation using Python"
playlists = sp.user_playlists(username)
    # print(playlists)
for playlist in playlists['items']:  # iterate through playlists I follow
    if playlist['name'] == playlist_name_recommend:  # filter for newly created playlist
        playlist_id_recommend = playlist['id']
print(playlist_id_recommend)
# Out:
# 5EN6nsAY8Qzry6DC9WJLjz

# %%
my_file = open("D:\SEMESTER6\BI\JCOMP\yash.txt", "r")
list=[]
data = my_file.read()
for i in range(15):
    list.append(data[55*i:55*(i+1)])
my_file.close()

str=''
str= list[0] + list[1] + list[2]
print(str)
# Out:
#                                  Kerina
#                                 Higher
#                           Fun, Fun, Fun
#      For Emily, Whenever I May Find Her

# %%
import openai
import requests
import json
openai.api_key = "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"  # supply your API key however you choose
DATA_DIR= "D:\SEMESTER6\BI\JCOMP"
image_resp = openai.Image.create(prompt=str, n=1, size="256x256" , response_format="b64_json")
print(image_resp)
# print(image_resp["data"][0]["b64_json"][:50])
# image_url = image_resp["data"]
# image = requests.get(image_url)
# with open("{}.png".format("BIyash"), "wb") as f:
#     f.write(image.content)
file_name = "D:\SEMESTER6\BI\JCOMP\yashBI.json"

with open(file_name, mode="w", encoding="utf-8") as file:
    json.dump(image_resp, file)
# Out:
# {
#   "created": 1680190911,
#   "data": [
#     {
#       "b64_json": "..."
#     }
#   ]
# }

# %%
from base64 import b64decode
import json
JSON_FILE = "D:\SEMESTER6\BI\JCOMP\yashBI.json"
# IMAGE_DIR="D:\SEMESTER6\BI\JCOMP\yashBI"
with open(JSON_FILE, mode="r", encoding="utf-8") as file:
    response = json.load(file)
for index, image_dict in enumerate(response["data"]):
    image_data = b64decode(image_dict["b64_json"])
    image_file = "D:\SEMESTER6\BI\JCOMP\chalgaya.png"
    with open(image_file, mode="wb") as png:
        png.write(image_data)

# %%
sp.playlist_upload_cover_image(playlist_id_recommend, image_resp["data"][0]["b64_json"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5900\1773491876.py in <module>
# ----> 1 sp.playlist_upload_cover_image(playlist_id_recommend, image_resp["data"][0]["b64_json"])
#
# NameError: name 'image_resp' is not defined

# %%
import base64
with open('D:\SEMESTER6\BI\JCOMP\pexels-alem-sánchez-2760229.jpg', 'rb') as image_file:
    encoded_image = base64.b64encode(image_file.read())
print(encoded_image)
# Out:
# b'...'

# %%
sp.playlist_upload_cover_image(playlist_id_recommend, encoded_image)
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# c:\Users\YRB\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# c:\Users\YRB\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#
# c:\Users\YRB\anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     243             headers["User-Agent"] = _get_default_user_agent()
# ...
